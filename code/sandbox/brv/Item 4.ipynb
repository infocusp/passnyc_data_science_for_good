# %%
import re

import numpy as np
import pandas as pd

import folium
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV

seed = 7
np.random.seed(seed=seed)

# %%
df = pd.read_csv('../../../input/2016 School Explorer.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1272 entries, 0 to 1271
# Columns: 161 entries, Adjusted Grade to Grade 8 Math 4s - Economically Disadvantaged
# dtypes: float64(5), int64(123), object(33)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#            SED Code    District     Latitude    Longitude           Zip  \
# count  1.272000e+03  1272.00000  1272.000000  1272.000000   1272.000000
# mean   3.286698e+11    16.13522    40.734537   -73.918347  10815.720912
# std    1.222022e+10     9.24527     0.086602     0.080576    529.588875
# min    3.075000e+11     1.00000    40.507803   -74.244025  10001.000000
# 25%    3.208752e+11     9.00000    40.669499   -73.957057  10452.000000
# 50%    3.315004e+11    15.00000    40.722995   -73.920571  11203.000000
# 75%    3.424000e+11    24.00000    40.815632   -73.879264  11232.000000
# max    3.531009e+11    32.00000    40.903455   -73.708920  11694.000000
#
#        Economic Need Index  Average ELA Proficiency  Average Math Proficiency  \
# count          1247.000000              1217.000000               1217.000000
# mean              0.672281                 2.534215                  2.668956
# std               0.210959                 0.363589                  0.470470
# min               0.049000                 1.810000                  1.830000
# 25%               0.550000                 2.250000                  2.300000
# 50%               0.731000                 2.450000                  2.580000
# 75%               0.841000                 2.760000                  2.980000
# max               0.957000                 3.930000                  4.200000
#
#        Grade 3 ELA - All Students Tested  Grade 3 ELA 4s - All Students  \
# count                        1272.000000                    1272.000000
# mean                           60.569182                       4.952830
# std                            57.872496                       8.300568
# min                             0.000000                       0.000000
# 25%                             0.000000                       0.000000
# 50%                            54.000000                       1.000000
# 75%                            94.000000                       7.000000
# max                           356.000000                      55.000000
#
#                            ...                       \
# count                      ...
# mean                       ...
# std                        ...
# min                        ...
# 25%                        ...
# 50%                        ...
# 75%                        ...
# max                        ...
#
#        Grade 8 Math - All Students Tested  Grade 8 Math 4s - All Students  \
# count                         1272.000000                     1272.000000
# mean                            43.841195                        4.911950
# std                             82.878780                       20.792371
# min                              0.000000                        0.000000
# 25%                              0.000000                        0.000000
# 50%                              0.000000                        0.000000
# 75%                             59.000000                        1.000000
# max                            652.000000                      312.000000
#
#        Grade 8 Math 4s - American Indian or Alaska Native  \
# count                                        1272.000000
# mean                                            0.003145
# std                                             0.068635
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             2.000000
#
#        Grade 8 Math 4s - Black or African American  \
# count                                  1272.000000
# mean                                      0.610063
# std                                       3.966083
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                     107.000000
#
#        Grade 8 Math 4s - Hispanic or Latino  \
# count                           1272.000000
# mean                               0.947327
# std                                4.056007
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                               71.000000
#
#        Grade 8 Math 4s - Asian or Pacific Islander  Grade 8 Math 4s - White  \
# count                                  1272.000000              1272.000000
# mean                                      1.984277                 0.970912
# std                                      12.841333                 6.880223
# min                                       0.000000                 0.000000
# 25%                                       0.000000                 0.000000
# 50%                                       0.000000                 0.000000
# 75%                                       0.000000                 0.000000
# max                                     246.000000               126.000000
#
#        Grade 8 Math 4s - Multiracial  \
# count                    1272.000000
# mean                        0.002358
# std                         0.084116
# min                         0.000000
# 25%                         0.000000
# 50%                         0.000000
# 75%                         0.000000
# max                         3.000000
#
#        Grade 8 Math 4s - Limited English Proficient  \
# count                                   1272.000000
# mean                                       0.159591
# std                                        1.321195
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                       33.000000
#
#        Grade 8 Math 4s - Economically Disadvantaged
# count                                   1272.000000
# mean                                       2.992138
# std                                       12.694124
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                      196.000000
#
# [8 rows x 128 columns]

# %%
df_registration = pd.read_csv('../../../input/2017-2018 SHSAT Admissions Test Offers By Sending School.csv')

# %%
df_merged = df.merge(df_registration[['School DBN', 
                                      'Borough', 
                                      'School Category', 
                                      'Number of students who took test']], 
                     left_on='Location Code', 
                     right_on='School DBN', 
                     how='inner')

# %%
df_merged['IsCommunitySchool'] = (df_merged['Community School?'] == 'Yes').astype('float')

percent_pattern = r'Percent\s.*'
percent_regex = re.compile(percent_pattern, re.IGNORECASE)

for col in df_merged.columns.values:
    if percent_regex.search(col):
        print col
        df_merged[col] = df_merged[col].astype(np.object).str.replace('%', '').astype(float)
df_merged['School Income Estimate'] = df_merged['School Income Estimate'].astype(np.object).str.replace('$', '').str.replace(',', '').str.replace('.', '').astype(float)
df_merged['Student Attendance Rate'] = df_merged['Student Attendance Rate'].astype(np.object).str.replace('%', '').astype(float)
df_merged['Percent of Students Chronically Absent'] = df_merged['Percent of Students Chronically Absent'].astype(np.object).str.replace('%', '').astype(float)

df_merged['Grade High'] = df_merged['Grade High'].astype(np.object_)
df_merged['Grade High'] = df_merged['Grade High'].str.replace('0K', '00')
df_merged['Grade High'] = df_merged['Grade High'].str.replace('PK', '00')

SPI_columns = ['Rigorous Instruction %', 'Collaborative Teachers %', 'Supportive Environment %', 
               'Effective School Leadership %', 'Strong Family-Community Ties %', 'Trust %']
for col in SPI_columns:
    df_merged[col] = df_merged[col].astype(np.object).str.replace('%', '').astype(float)

df_merged['SPI'] = df_merged['Supportive Environment %'] \
                 + 0.8 * df_merged['Rigorous Instruction %'] \
                 + 0.7 * df_merged['Effective School Leadership %'] \
                 + 0.5 * df_merged['Strong Family-Community Ties %']
# Out:
# Percent ELL
# Percent Asian
# Percent Black
# Percent Hispanic
# Percent Black / Hispanic
# Percent White
# Percent of Students Chronically Absent

# %%
drop_columns = ['SED Code', 'Location Code', 'Community School?', 'School Name', 'Grades', 'Grade Low', 
                'School DBN', 'Zip', 'Address (Full)', 'School Category', 'Other Location Code in LCGMS', 
                'Adjusted Grade', 'New?', 'Strong Family-Community Ties Rating', 'Trust Rating', 
                'Student Achievement Rating', 'Effective School Leadership Rating', 'Longitude', 'Latitude', 
                'Supportive Environment Rating', 'Collaborative Teachers Rating', 'Rigorous Instruction Rating', 
                'School Income Estimate'] + SPI_columns
df_merged = df_merged.drop(columns=drop_columns)

# %%
# df_merged = df_merged.dropna()
df_merged = df_merged.fillna(0)

# %%
label_encode_columns = ['City', 'District', 'Borough']

label_encoders = []
for col in label_encode_columns:
    label_encoder = LabelEncoder()
    label_encoder.fit(df_merged[col])
    df_merged[col] = label_encoder.transform(df_merged[col].values)
    
    label_encoders.append(label_encoder)

# %%
# nan_percentage = df_merged.isnull().mean().sort_values(ascending=False)*100
# columns_to_keep = list(nan_percentage[nan_percentage <= 0].index.values)
# columns_to_keep.append('Number of students who took test')

columns_to_keep = list(df_merged.columns.values)
df_merged = df_merged[columns_to_keep]

# %%
df_merged = df_merged.astype('float')
df_merged = df_merged.dropna()

# %%
feature_list = list(columns_to_keep)
feature_list.remove('Number of students who took test')

# %%
X_train = df_merged[feature_list]
y_train = df_merged['Number of students who took test']

y_train = (y_train > y_train.mean()).astype('float')

# %%
model = LogisticRegressionCV(cv=5, n_jobs=-1, tol=1e-10, max_iter=1**10, random_state=seed)
model.fit(X_train, y_train)
# Out:
# LogisticRegressionCV(Cs=10, class_weight=None, cv=5, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=1,
#            multi_class='ovr', n_jobs=-1, penalty='l2', random_state=7,
#            refit=True, scoring=None, solver='lbfgs', tol=1e-10, verbose=0)

# %%
preds = model.predict(X_train)
print classification_report(y_train, preds)
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.89      0.98      0.93       438
#         1.0       0.93      0.62      0.74       142
#
# avg / total       0.90      0.89      0.89       580

# %%
temp = df_merged[preds==1]
# temp['School Income Estimate'].describe()

# %%
model.coef_[0]
# Out:
# array([-4.99893626e-04, -6.10113172e-04, -5.33006111e-04, -5.67183290e-05,
#        -1.17526193e-03,  1.69470915e-03, -3.33063469e-03, -4.73340781e-03,
#        -8.06856570e-03,  9.81148100e-04, -3.68590577e-03,  0.00000000e+00,
#        -5.68307225e-05, -4.58503341e-05,  8.61650492e-04,  4.44851934e-04,
#         0.00000000e+00,  7.32256051e-05,  1.98695971e-06,  2.32337599e-04,
#         1.26419729e-04,  5.38182563e-06, -1.37460703e-06,  1.92262726e-04,
#         9.09999244e-04,  9.55230129e-04, -4.28419677e-06,  2.04408779e-04,
#        -3.21160343e-05,  5.28466756e-04,  2.04569964e-04,  4.96166751e-06,
#         5.62821321e-06,  5.93383373e-04,  1.03070171e-03,  8.17233962e-04,
#        -1.49945778e-06,  1.68493288e-04, -7.38864050e-06,  3.59992918e-04,
#         2.18319462e-04,  1.12736291e-05,  2.65260163e-06,  3.50388622e-04,
#         1.06645327e-03,  1.06653412e-03, -5.99783112e-06,  2.09829704e-04,
#         1.08659847e-05,  5.07664281e-04,  2.52815400e-04,  1.25954161e-05,
#         2.18051556e-05,  3.99649237e-04,  9.34008605e-04,  5.85347514e-04,
#        -4.47084876e-07,  5.90353517e-05,  6.79401195e-06,  2.50209047e-04,
#         1.89801628e-04,  7.94164003e-06, -8.59364582e-07,  2.43565719e-04,
#         9.24355875e-04,  6.76774079e-04,  2.19385972e-06, -7.18839033e-06,
#        -6.27382816e-06,  4.13547846e-04,  2.00673730e-04,  1.59847476e-06,
#         4.97933871e-06,  2.83877219e-04,  3.82481310e-03,  3.22032297e-03,
#         1.34081009e-05,  3.48852219e-04,  2.88123573e-04,  1.26403687e-03,
#         1.08696285e-03,  4.92097221e-05, -1.87841690e-06,  1.47257500e-03,
#         3.78231537e-03,  4.74095159e-03,  1.03079981e-05,  4.73597434e-04,
#         3.82446701e-04,  2.11379223e-03,  1.45718626e-03,  2.76404778e-05,
#         8.96840034e-05,  2.30712220e-03,  3.58468356e-03,  2.83633482e-03,
#         1.23051985e-06,  9.59200658e-05,  2.75053239e-04,  1.11639225e-03,
#         1.03233415e-03,  1.99953635e-05,  4.29056025e-07,  1.16684462e-03,
#         3.59977655e-03,  3.59866377e-03,  8.64308425e-06,  4.46469908e-05,
#         2.40346563e-04,  1.70460767e-03,  1.21092763e-03,  2.11130582e-05,
#         3.83004302e-05,  1.73118291e-03,  2.87848290e-03,  2.95862215e-03,
#         7.94137692e-06,  2.28178129e-04,  2.93490648e-04,  1.11746421e-03,
#         9.84916991e-04,  7.33282002e-06,  2.43205264e-06,  1.36137607e-03,
#        -3.70963404e-04,  1.43414337e-03,  5.83271540e-07,  8.14677499e-05,
#         3.11584309e-05,  7.90152379e-04,  4.06696923e-04,  4.10234474e-07,
#         5.87163541e-05,  8.72704734e-04, -6.56777472e-05, -1.41651740e-05,
#        -1.09056404e-02])

# %%
feature_importance = model.coef_[0]

feature_importance_dict = dict(zip(feature_list, feature_importance))
feature_importance_dict = sorted(feature_importance_dict.iteritems(), key=lambda (k, v): (abs(v), k), reverse=True)
feature_importance_dict
# Out:
# [('SPI', -0.010905640363396732),
#  ('Percent Black / Hispanic', -0.008068565699144045),
#  ('Grade 6 Math 4s - All Students', 0.004740951590366564),
#  ('Percent Hispanic', -0.004733407812306094),
#  ('Grade 6 ELA - All Students Tested', 0.003824813097030612),
#  ('Grade 6 Math - All Students Tested', 0.003782315374296638),
#  ('Student Attendance Rate', -0.0036859057670690404),
#  ('Grade 7 Math - All Students Tested', 0.0035997765492203995),
#  ('Grade 7 Math 4s - All Students', 0.003598663771591201),
#  ('Grade 7 ELA - All Students Tested', 0.0035846835638423573),
#  ('Percent Black', -0.003330634694264705),
#  ('Grade 6 ELA 4s - All Students', 0.003220322965210863),
#  ('Grade 8 ELA 4s - All Students', 0.002958622145008441),
#  ('Grade 8 ELA - All Students Tested', 0.0028784828953764357),
#  ('Grade 7 ELA 4s - All Students', 0.002836334821294208),
#  ('Grade 6 Math 4s - Economically Disadvantaged', 0.0023071222012222537),
#  ('Grade 6 Math 4s - Asian or Pacific Islander', 0.0021137922257732796),
#  ('Grade 7 Math 4s - Economically Disadvantaged', 0.001731182910752439),
#  ('Grade 7 Math 4s - Asian or Pacific Islander', 0.0017046076739399942),
#  ('Percent Asian', 0.0016947091505188617),
#  ('Grade 6 ELA 4s - Economically Disadvantaged', 0.0014725750027624119),
#  ('Grade 6 Math 4s - White', 0.001457186256251801),
#  ('Grade 8 Math 4s - All Students', 0.0014341433677233046),
#  ('Grade 8 ELA 4s - Economically Disadvantaged', 0.0013613760744415303),
#  ('Grade 6 ELA 4s - Asian or Pacific Islander', 0.0012640368668189314),
#  ('Grade 7 Math 4s - White', 0.001210927632968624),
#  ('Percent ELL', -0.001175261931783054),
#  ('Grade 7 ELA 4s - Economically Disadvantaged', 0.0011668446154690442),
#  ('Grade 8 ELA 4s - Asian or Pacific Islander', 0.0011174642083002467),
#  ('Grade 7 ELA 4s - Asian or Pacific Islander', 0.001116392248252775),
#  ('Grade 6 ELA 4s - White', 0.0010869628492522236),
#  ('Grade 4 Math 4s - All Students', 0.0010665341238576982),
#  ('Grade 4 Math - All Students Tested', 0.001066453268966716),
#  ('Grade 7 ELA 4s - White', 0.0010323341493311945),
#  ('Grade 4 ELA - All Students Tested', 0.001030701711889121),
#  ('Grade 8 ELA 4s - White', 0.0009849169912005571),
#  ('Percent White', 0.000981148100064041),
#  ('Grade 3 Math 4s - All Students', 0.0009552301294974404),
#  ('Grade 5 ELA - All Students Tested', 0.000934008604564091),
#  ('Grade 5 Math - All Students Tested', 0.0009243558747068019),
#  ('Grade 3 Math - All Students tested', 0.0009099992440752395),
#  ('Grade 8 Math 4s - Economically Disadvantaged', 0.0008727047341844144),
#  ('Grade 3 ELA - All Students Tested', 0.0008616504918780542),
#  ('Grade 4 ELA 4s - All Students', 0.0008172339624985974),
#  ('Grade 8 Math 4s - Asian or Pacific Islander', 0.0007901523787814547),
#  ('Grade 5 Math 4s - All Students', 0.0006767740788806485),
#  ('City', -0.000610113172173696),
#  ('Grade 3 Math 4s - Economically Disadvantaged', 0.000593383372663599),
#  ('Grade 5 ELA 4s - All Students', 0.0005853475142048798),
#  ('Grade High', -0.0005330061111080131),
#  ('Grade 3 Math 4s - Asian or Pacific Islander', 0.0005284667559582714),
#  ('Grade 4 Math 4s - Asian or Pacific Islander', 0.0005076642807392052),
#  ('District', -0.0004998936259549506),
#  ('Grade 6 Math 4s - Black or African American', 0.00047359743357835207),
#  ('Grade 3 ELA 4s - All Students', 0.0004448519340214538),
#  ('Grade 5 Math 4s - Asian or Pacific Islander', 0.00041354784551593803),
#  ('Grade 8 Math 4s - White', 0.00040669692329574797),
#  ('Grade 4 Math 4s - Economically Disadvantaged', 0.0003996492371957822),
#  ('Grade 6 Math 4s - Hispanic or Latino', 0.0003824467009718178),
#  ('Grade 8 Math - All Students Tested', -0.0003709634035063438),
#  ('Grade 4 ELA 4s - Asian or Pacific Islander', 0.00035999291813840846),
#  ('Grade 4 ELA 4s - Economically Disadvantaged', 0.0003503886223781932),
#  ('Grade 6 ELA 4s - Black or African American', 0.00034885221856956487),
#  ('Grade 8 ELA 4s - Hispanic or Latino', 0.0002934906476276976),
#  ('Grade 6 ELA 4s - Hispanic or Latino', 0.0002881235733853182),
#  ('Grade 5 Math 4s - Economically Disadvantaged', 0.00028387721934867473),
#  ('Grade 7 ELA 4s - Hispanic or Latino', 0.0002750532389232968),
#  ('Grade 4 Math 4s - White', 0.00025281540042620173),
#  ('Grade 5 ELA 4s - Asian or Pacific Islander', 0.00025020904676783205),
#  ('Grade 5 ELA 4s - Economically Disadvantaged', 0.0002435657188797273),
#  ('Grade 7 Math 4s - Hispanic or Latino', 0.00024034656295390526),
#  ('Grade 3 ELA 4s - Asian or Pacific Islander', 0.00023233759948387505),
#  ('Grade 8 ELA 4s - Black or African American', 0.00022817812868965114),
#  ('Grade 4 ELA 4s - White', 0.00021831946242599566),
#  ('Grade 4 Math 4s - Black or African American', 0.0002098297041856458),
#  ('Grade 3 Math 4s - White', 0.00020456996406983559),
#  ('Grade 3 Math 4s - Black or African American', 0.00020440877908123241),
#  ('Grade 5 Math 4s - White', 0.00020067373005810136),
#  ('Grade 3 ELA 4s - Economically Disadvantaged', 0.00019226272572415992),
#  ('Grade 5 ELA 4s - White', 0.00018980162755447396),
#  ('Grade 4 ELA 4s - Black or African American', 0.0001684932882098498),
#  ('Grade 3 ELA 4s - White', 0.00012641972922960396),
#  ('Grade 7 ELA 4s - Black or African American', 9.59200657968627e-05),
#  ('Grade 6 Math 4s - Limited English Proficient', 8.968400341068641e-05),
#  ('Grade 8 Math 4s - Black or African American', 8.146774989775506e-05),
#  ('Grade 3 ELA 4s - Black or African American', 7.322560513196615e-05),
#  ('Borough', -6.567774716399487e-05),
#  ('Grade 5 ELA 4s - Black or African American', 5.903535173186673e-05),
#  ('Grade 8 Math 4s - Limited English Proficient', 5.871635406477751e-05),
#  ('Average ELA Proficiency', -5.6830722470740286e-05),
#  ('Economic Need Index', -5.671832904448206e-05),
#  ('Grade 6 ELA 4s - Multiracial', 4.9209722099642135e-05),
#  ('Average Math Proficiency', -4.585033405791397e-05),
#  ('Grade 7 Math 4s - Black or African American', 4.46469908443056e-05),
#  ('Grade 7 Math 4s - Limited English Proficient', 3.83004302143678e-05),
#  ('Grade 3 Math 4s - Hispanic or Latino', -3.211603428088271e-05),
#  ('Grade 8 Math 4s - Hispanic or Latino', 3.115843086573896e-05),
#  ('Grade 6 Math 4s - Multiracial', 2.764047777449447e-05),
#  ('Grade 4 Math 4s - Limited English Proficient', 2.1805155607428946e-05),
#  ('Grade 7 Math 4s - Multiracial', 2.1113058161479775e-05),
#  ('Grade 7 ELA 4s - Multiracial', 1.9995363496736536e-05),
#  ('IsCommunitySchool', -1.4165173985419131e-05),
#  ('Grade 6 ELA 4s - American Indian or Alaska Native', 1.3408100864019866e-05),
#  ('Grade 4 Math 4s - Multiracial', 1.2595416097591364e-05),
#  ('Grade 4 ELA 4s - Multiracial', 1.1273629136788327e-05),
#  ('Grade 4 Math 4s - Hispanic or Latino', 1.0865984731009098e-05),
#  ('Grade 6 Math 4s - American Indian or Alaska Native',
#   1.0307998135585948e-05),
#  ('Grade 7 Math 4s - American Indian or Alaska Native', 8.643084252619816e-06),
#  ('Grade 5 ELA 4s - Multiracial', 7.941640033374985e-06),
#  ('Grade 8 ELA 4s - American Indian or Alaska Native', 7.941376916846867e-06),
#  ('Grade 4 ELA 4s - Hispanic or Latino', -7.3886405047698965e-06),
#  ('Grade 8 ELA 4s - Multiracial', 7.332820023711872e-06),
#  ('Grade 5 Math 4s - Black or African American', -7.188390326403189e-06),
#  ('Grade 5 ELA 4s - Hispanic or Latino', 6.794011946510739e-06),
#  ('Grade 5 Math 4s - Hispanic or Latino', -6.273828164314735e-06),
#  ('Grade 4 Math 4s - American Indian or Alaska Native',
#   -5.997831121598862e-06),
#  ('Grade 3 Math 4s - Limited English Proficient', 5.628213205892392e-06),
#  ('Grade 3 ELA 4s - Multiracial', 5.38182563160758e-06),
#  ('Grade 5 Math 4s - Limited English Proficient', 4.979338709336152e-06),
#  ('Grade 3 Math 4s - Multiracial', 4.961667507398548e-06),
#  ('Grade 3 Math 4s - American Indian or Alaska Native', -4.28419677498647e-06),
#  ('Grade 4 ELA 4s - Limited English Proficient', 2.6526016277893753e-06),
#  ('Grade 8 ELA 4s - Limited English Proficient', 2.4320526399631e-06),
#  ('Grade 5 Math 4s - American Indian or Alaska Native', 2.19385972207472e-06),
#  ('Grade 3 ELA 4s - Hispanic or Latino', 1.9869597137613184e-06),
#  ('Grade 6 ELA 4s - Limited English Proficient', -1.8784168971240076e-06),
#  ('Grade 5 Math 4s - Multiracial', 1.598474756238781e-06),
#  ('Grade 4 ELA 4s - American Indian or Alaska Native',
#   -1.4994577803997154e-06),
#  ('Grade 3 ELA 4s - Limited English Proficient', -1.3746070334854993e-06),
#  ('Grade 7 ELA 4s - American Indian or Alaska Native', 1.2305198532024591e-06),
#  ('Grade 5 ELA 4s - Limited English Proficient', -8.593645817416473e-07),
#  ('Grade 8 Math 4s - American Indian or Alaska Native', 5.832715404880035e-07),
#  ('Grade 5 ELA 4s - American Indian or Alaska Native',
#   -4.4708487608681374e-07),
#  ('Grade 7 ELA 4s - Limited English Proficient', 4.2905602465838186e-07),
#  ('Grade 8 Math 4s - Multiracial', 4.1023447414451644e-07),
#  ('Percent of Students Chronically Absent', 0.0),
#  ('Grade 3 ELA 4s - American Indian or Alaska Native', 0.0)]

# %%
feature_importance = np.abs(model.coef_[0])

feature_importance_min = feature_importance.min()
feature_importance_max = feature_importance.max()
feature_importance = (feature_importance - feature_importance_min) / (feature_importance_max - feature_importance_min)

feature_importance_dict = dict(zip(feature_list, feature_importance))
feature_importance_dict = sorted(feature_importance_dict.iteritems(), key=lambda (k, v): (abs(v), k), reverse=True)
feature_importance_dict
# Out:
# [('SPI', 1.0),
#  ('Percent Black / Hispanic', 0.7398525377954939),
#  ('Grade 6 Math 4s - All Students', 0.4347247325593928),
#  ('Percent Hispanic', 0.43403300077573803),
#  ('Grade 6 ELA - All Students Tested', 0.35071879959182095),
#  ('Grade 6 Math - All Students Tested', 0.34682194243186804),
#  ('Student Attendance Rate', 0.33798159890181884),
#  ('Grade 7 Math - All Students Tested', 0.33008392256382757),
#  ('Grade 7 Math 4s - All Students', 0.3299818856735471),
#  ('Grade 7 ELA - All Students Tested', 0.3286999611571504),
#  ('Percent Black', 0.30540477984617187),
#  ('Grade 6 ELA 4s - All Students', 0.29528967194071704),
#  ('Grade 8 ELA 4s - All Students', 0.2712928398903237),
#  ('Grade 8 ELA - All Students Tested', 0.26394441770129007),
#  ('Grade 7 ELA 4s - All Students', 0.2600796218087268),
#  ('Grade 6 Math 4s - Economically Disadvantaged', 0.21155311603395516),
#  ('Grade 6 Math 4s - Asian or Pacific Islander', 0.1938255944023177),
#  ('Grade 7 Math 4s - Economically Disadvantaged', 0.15874197690975708),
#  ('Grade 7 Math 4s - Asian or Pacific Islander', 0.15630514276458934),
#  ('Percent Asian', 0.15539749102738779),
#  ('Grade 6 ELA 4s - Economically Disadvantaged', 0.13502875151695864),
#  ('Grade 6 Math 4s - White', 0.13361767009506792),
#  ('Grade 8 Math 4s - All Students', 0.1315047369925023),
#  ('Grade 8 ELA 4s - Economically Disadvantaged', 0.12483229128028099),
#  ('Grade 6 ELA 4s - Asian or Pacific Islander', 0.11590670741917142),
#  ('Grade 7 Math 4s - White', 0.11103682063759726),
#  ('Percent ELL', 0.10776643027104191),
#  ('Grade 7 ELA 4s - Economically Disadvantaged', 0.10699459881195021),
#  ('Grade 8 ELA 4s - Asian or Pacific Islander', 0.10246662929128492),
#  ('Grade 7 ELA 4s - Asian or Pacific Islander', 0.10236833519650901),
#  ('Grade 6 ELA 4s - White', 0.09966978673718817),
#  ('Grade 4 Math 4s - All Students', 0.09779656107470515),
#  ('Grade 4 Math - All Students Tested', 0.09778914703130304),
#  ('Grade 7 ELA 4s - White', 0.09466057149620308),
#  ('Grade 4 ELA - All Students Tested', 0.0945108840512042),
#  ('Grade 8 ELA 4s - White', 0.09031262341148662),
#  ('Percent White', 0.0899670324135324),
#  ('Grade 3 Math 4s - All Students', 0.08759046673715169),
#  ('Grade 5 ELA - All Students Tested', 0.0856445447897733),
#  ('Grade 5 Math - All Students Tested', 0.08475943125809228),
#  ('Grade 3 Math - All Students tested', 0.08344299039325793),
#  ('Grade 8 Math 4s - Economically Disadvantaged', 0.08002324532115754),
#  ('Grade 3 ELA - All Students Tested', 0.07900961916643286),
#  ('Grade 4 ELA 4s - All Students', 0.07493681574550448),
#  ('Grade 8 Math 4s - Asian or Pacific Islander', 0.07245355178165341),
#  ('Grade 5 Math 4s - All Students', 0.062057252607755777),
#  ('City', 0.05594473610384734),
#  ('Grade 3 Math 4s - Economically Disadvantaged', 0.05441068592865101),
#  ('Grade 5 ELA 4s - All Students', 0.05367383250318041),
#  ('Grade High', 0.0488743524769966),
#  ('Grade 3 Math 4s - Asian or Pacific Islander', 0.04845811326513174),
#  ('Grade 4 Math 4s - Asian or Pacific Islander', 0.046550616362071674),
#  ('District', 0.04583808096521999),
#  ('Grade 6 Math 4s - Black or African American', 0.04342683398655948),
#  ('Grade 3 ELA 4s - All Students', 0.04079099614494327),
#  ('Grade 5 Math 4s - Asian or Pacific Islander', 0.037920546775405684),
#  ('Grade 8 Math 4s - White', 0.03729234687224509),
#  ('Grade 4 Math 4s - Economically Disadvantaged', 0.036646104573294876),
#  ('Grade 6 Math 4s - Hispanic or Latino', 0.03506870648838257),
#  ('Grade 8 Math - All Students Tested', 0.03401573783337208),
#  ('Grade 4 ELA 4s - Asian or Pacific Islander', 0.03300979182723416),
#  ('Grade 4 ELA 4s - Economically Disadvantaged', 0.03212911949253562),
#  ('Grade 6 ELA 4s - Black or African American', 0.03198823791589891),
#  ('Grade 8 ELA 4s - Hispanic or Latino', 0.0269118215756278),
#  ('Grade 6 ELA 4s - Hispanic or Latino', 0.026419684106984215),
#  ('Grade 5 Math 4s - Economically Disadvantaged', 0.026030311828498326),
#  ('Grade 7 ELA 4s - Hispanic or Latino', 0.025221191031246072),
#  ('Grade 4 Math 4s - White', 0.023182077530700673),
#  ('Grade 5 ELA 4s - Asian or Pacific Islander', 0.022943086185715788),
#  ('Grade 5 ELA 4s - Economically Disadvantaged', 0.022333921783925847),
#  ('Grade 7 Math 4s - Hispanic or Latino', 0.022038739124443818),
#  ('Grade 3 ELA 4s - Asian or Pacific Islander', 0.021304351852980952),
#  ('Grade 8 ELA 4s - Black or African American', 0.02092294639162129),
#  ('Grade 4 ELA 4s - White', 0.020018949383179243),
#  ('Grade 4 Math 4s - Black or African American', 0.019240475313115044),
#  ('Grade 3 Math 4s - White', 0.01875817991912206),
#  ('Grade 3 Math 4s - Black or African American', 0.01874339995359668),
#  ('Grade 5 Math 4s - White', 0.018400912130903828),
#  ('Grade 3 ELA 4s - Economically Disadvantaged', 0.017629659453053583),
#  ('Grade 5 ELA 4s - White', 0.017403987407426047),
#  ('Grade 4 ELA 4s - Black or African American', 0.015450104954439369),
#  ('Grade 3 ELA 4s - White', 0.011592141774078139),
#  ('Grade 7 ELA 4s - Black or African American', 0.008795454700560737),
#  ('Grade 6 Math 4s - Limited English Proficient', 0.008223634781841726),
#  ('Grade 8 Math 4s - Black or African American', 0.007470239911008825),
#  ('Grade 3 ELA 4s - Black or African American', 0.0067144709243977755),
#  ('Borough', 0.006022365030891089),
#  ('Grade 5 ELA 4s - Black or African American', 0.005413286131276682),
#  ('Grade 8 Math 4s - Limited English Proficient', 0.005384035426461595),
#  ('Average ELA Proficiency', 0.005211131174056016),
#  ('Economic Need Index', 0.005200825183530648),
#  ('Grade 6 ELA 4s - Multiracial', 0.004512318438888534),
#  ('Average Math Proficiency', 0.004204277101581696),
#  ('Grade 7 Math 4s - Black or African American', 0.004093935739358967),
#  ('Grade 7 Math 4s - Limited English Proficient', 0.003511983610143415),
#  ('Grade 3 Math 4s - Hispanic or Latino', 0.0029449012814209167),
#  ('Grade 8 Math 4s - Hispanic or Latino', 0.0028570931946663037),
#  ('Grade 6 Math 4s - Multiracial', 0.002534512128904039),
#  ('Grade 4 Math 4s - Limited English Proficient', 0.0019994383530759848),
#  ('Grade 7 Math 4s - Multiracial', 0.0019359760140580853),
#  ('Grade 7 ELA 4s - Multiracial', 0.0018334882529088524),
#  ('IsCommunitySchool', 0.001298885119388548),
#  ('Grade 6 ELA 4s - American Indian or Alaska Native', 0.001229464792275958),
#  ('Grade 4 Math 4s - Multiracial', 0.0011549451181121035),
#  ('Grade 4 ELA 4s - Multiracial', 0.0010337429771319709),
#  ('Grade 4 Math 4s - Hispanic or Latino', 0.0009963637502185812),
#  ('Grade 6 Math 4s - American Indian or Alaska Native', 0.0009451987954951561),
#  ('Grade 7 Math 4s - American Indian or Alaska Native', 0.0007925334014891164),
#  ('Grade 5 ELA 4s - Multiracial', 0.0007282140038314483),
#  ('Grade 8 ELA 4s - American Indian or Alaska Native', 0.000728189877185112),
#  ('Grade 4 ELA 4s - Hispanic or Latino', 0.0006775063415412856),
#  ('Grade 8 ELA 4s - Multiracial', 0.0006723878451304395),
#  ('Grade 5 Math 4s - Black or African American', 0.0006591442672665076),
#  ('Grade 5 ELA 4s - Hispanic or Latino', 0.0006229814774851642),
#  ('Grade 5 Math 4s - Hispanic or Latino', 0.0005752828770488313),
#  ('Grade 4 Math 4s - American Indian or Alaska Native', 0.0005499751432964679),
#  ('Grade 3 Math 4s - Limited English Proficient', 0.0005160827808683943),
#  ('Grade 3 ELA 4s - Multiracial', 0.0004934901071624305),
#  ('Grade 5 Math 4s - Limited English Proficient', 0.0004565837991548494),
#  ('Grade 3 Math 4s - Multiracial', 0.00045496342645331457),
#  ('Grade 3 Math 4s - American Indian or Alaska Native',
#   0.00039284229373323014),
#  ('Grade 4 ELA 4s - Limited English Proficient', 0.00024323208352738866),
#  ('Grade 8 ELA 4s - Limited English Proficient', 0.00022300869631882846),
#  ('Grade 5 Math 4s - American Indian or Alaska Native',
#   0.00020116743712162978),
#  ('Grade 3 ELA 4s - Hispanic or Latino', 0.00018219560223444307),
#  ('Grade 6 ELA 4s - Limited English Proficient', 0.00017224269593820948),
#  ('Grade 5 Math 4s - Multiracial', 0.00014657321376595542),
#  ('Grade 4 ELA 4s - American Indian or Alaska Native', 0.00013749378582411697),
#  ('Grade 3 ELA 4s - Limited English Proficient', 0.00012604551293468076),
#  ('Grade 7 ELA 4s - American Indian or Alaska Native', 0.00011283334239890472),
#  ('Grade 5 ELA 4s - Limited English Proficient', 7.880001110489442e-05),
#  ('Grade 8 Math 4s - American Indian or Alaska Native',
#   5.3483474702290154e-05),
#  ('Grade 5 ELA 4s - American Indian or Alaska Native', 4.099574726371796e-05),
#  ('Grade 7 ELA 4s - Limited English Proficient', 3.934257965249329e-05),
#  ('Grade 8 Math 4s - Multiracial', 3.7616724967514196e-05),
#  ('Percent of Students Chronically Absent', 0.0),
#  ('Grade 3 ELA 4s - American Indian or Alaska Native', 0.0)]
