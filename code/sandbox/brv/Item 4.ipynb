# %%
import re

import numpy as np
import pandas as pd

import folium
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV

# %%
df = pd.read_csv('../../../input/2016 School Explorer.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1272 entries, 0 to 1271
# Columns: 161 entries, Adjusted Grade to Grade 8 Math 4s - Economically Disadvantaged
# dtypes: float64(5), int64(123), object(33)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#            SED Code    District     Latitude    Longitude           Zip  \
# count  1.272000e+03  1272.00000  1272.000000  1272.000000   1272.000000
# mean   3.286698e+11    16.13522    40.734537   -73.918347  10815.720912
# std    1.222022e+10     9.24527     0.086602     0.080576    529.588875
# min    3.075000e+11     1.00000    40.507803   -74.244025  10001.000000
# 25%    3.208752e+11     9.00000    40.669499   -73.957057  10452.000000
# 50%    3.315004e+11    15.00000    40.722995   -73.920571  11203.000000
# 75%    3.424000e+11    24.00000    40.815632   -73.879264  11232.000000
# max    3.531009e+11    32.00000    40.903455   -73.708920  11694.000000
#
#        Economic Need Index  Average ELA Proficiency  Average Math Proficiency  \
# count          1247.000000              1217.000000               1217.000000
# mean              0.672281                 2.534215                  2.668956
# std               0.210959                 0.363589                  0.470470
# min               0.049000                 1.810000                  1.830000
# 25%               0.550000                 2.250000                  2.300000
# 50%               0.731000                 2.450000                  2.580000
# 75%               0.841000                 2.760000                  2.980000
# max               0.957000                 3.930000                  4.200000
#
#        Grade 3 ELA - All Students Tested  Grade 3 ELA 4s - All Students  \
# count                        1272.000000                    1272.000000
# mean                           60.569182                       4.952830
# std                            57.872496                       8.300568
# min                             0.000000                       0.000000
# 25%                             0.000000                       0.000000
# 50%                            54.000000                       1.000000
# 75%                            94.000000                       7.000000
# max                           356.000000                      55.000000
#
#                            ...                       \
# count                      ...
# mean                       ...
# std                        ...
# min                        ...
# 25%                        ...
# 50%                        ...
# 75%                        ...
# max                        ...
#
#        Grade 8 Math - All Students Tested  Grade 8 Math 4s - All Students  \
# count                         1272.000000                     1272.000000
# mean                            43.841195                        4.911950
# std                             82.878780                       20.792371
# min                              0.000000                        0.000000
# 25%                              0.000000                        0.000000
# 50%                              0.000000                        0.000000
# 75%                             59.000000                        1.000000
# max                            652.000000                      312.000000
#
#        Grade 8 Math 4s - American Indian or Alaska Native  \
# count                                        1272.000000
# mean                                            0.003145
# std                                             0.068635
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             2.000000
#
#        Grade 8 Math 4s - Black or African American  \
# count                                  1272.000000
# mean                                      0.610063
# std                                       3.966083
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                     107.000000
#
#        Grade 8 Math 4s - Hispanic or Latino  \
# count                           1272.000000
# mean                               0.947327
# std                                4.056007
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                               71.000000
#
#        Grade 8 Math 4s - Asian or Pacific Islander  Grade 8 Math 4s - White  \
# count                                  1272.000000              1272.000000
# mean                                      1.984277                 0.970912
# std                                      12.841333                 6.880223
# min                                       0.000000                 0.000000
# 25%                                       0.000000                 0.000000
# 50%                                       0.000000                 0.000000
# 75%                                       0.000000                 0.000000
# max                                     246.000000               126.000000
#
#        Grade 8 Math 4s - Multiracial  \
# count                    1272.000000
# mean                        0.002358
# std                         0.084116
# min                         0.000000
# 25%                         0.000000
# 50%                         0.000000
# 75%                         0.000000
# max                         3.000000
#
#        Grade 8 Math 4s - Limited English Proficient  \
# count                                   1272.000000
# mean                                       0.159591
# std                                        1.321195
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                       33.000000
#
#        Grade 8 Math 4s - Economically Disadvantaged
# count                                   1272.000000
# mean                                       2.992138
# std                                       12.694124
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                      196.000000
#
# [8 rows x 128 columns]

# %%
df_registration = pd.read_csv('../../../input/2017-2018 SHSAT Admissions Test Offers By Sending School.csv')

# %%
df_merged = df.merge(df_registration[['School DBN', 
                                      'Borough', 
                                      'School Category', 
                                      'Number of students who took test']], 
                     left_on='Location Code', 
                     right_on='School DBN', 
                     how='inner')

# %%
df_merged['IsCommunitySchool'] = (df_merged['Community School?'] == 'Yes').astype('float')

percent_pattern = r'Percent\s.*'
percent_regex = re.compile(percent_pattern, re.IGNORECASE)

for col in df_merged.columns.values:
    if percent_regex.search(col):
        print col
        df_merged[col] = df_merged[col].astype(np.object).str.replace('%', '').astype(float)
df_merged['School Income Estimate'] = df_merged['School Income Estimate'].astype(np.object).str.replace('$', '').str.replace(',', '').str.replace('.', '').astype(float)
df_merged['Student Attendance Rate'] = df_merged['Student Attendance Rate'].astype(np.object).str.replace('%', '').astype(float)
df_merged['Percent of Students Chronically Absent'] = df_merged['Percent of Students Chronically Absent'].astype(np.object).str.replace('%', '').astype(float)

df_merged['Grade High'] = df_merged['Grade High'].astype(np.object_)
df_merged['Grade High'] = df_merged['Grade High'].str.replace('0K', '00')
df_merged['Grade High'] = df_merged['Grade High'].str.replace('PK', '00')

SPI_columns = ['Rigorous Instruction %', 'Collaborative Teachers %', 'Supportive Environment %', 
               'Effective School Leadership %', 'Strong Family-Community Ties %', 'Trust %']
for col in SPI_columns:
    df_merged[col] = df_merged[col].astype(np.object).str.replace('%', '').astype(float)
# Out:
# Percent ELL
# Percent Asian
# Percent Black
# Percent Hispanic
# Percent Black / Hispanic
# Percent White
# Percent of Students Chronically Absent

# %%
drop_columns = ['SED Code', 'Location Code', 'Community School?', 'School Name', 'Grades', 'Grade Low', 
                'School DBN', 'Zip', 'Address (Full)', 'School Category']
df_merged = df_merged.drop(columns=drop_columns)

# %%
label_encode_columns = ['City', 'District', 'Borough']

label_encoders = []
for col in label_encode_columns:
    label_encoder = LabelEncoder()
    label_encoder.fit(df_merged[col])
    df_merged[col] = label_encoder.transform(df_merged[col].values)
    
    label_encoders.append(label_encoder)

# %%
nan_percentage = df_merged.isnull().mean().sort_values(ascending=False)*100
columns_to_keep = list(nan_percentage[nan_percentage <= 0].index.values)
columns_to_keep.append('Number of students who took test')

df_merged = df_merged[columns_to_keep]

# %%
df_merged = df_merged.astype('float')
df_merged = df_merged.dropna()

# %%
feature_list = list(columns_to_keep)
feature_list.remove('Number of students who took test')

# %%
X_train = df_merged[feature_list]
y_train = df_merged['Number of students who took test']

y_train = (y_train > y_train.median()).astype('float')

# %%
model = LogisticRegressionCV(cv=5, n_jobs=-1, tol=1e-10, max_iter=1**10)
model.fit(X_train, y_train)
# Out:
# LogisticRegressionCV(Cs=10, class_weight=None, cv=5, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=1,
#            multi_class='ovr', n_jobs=-1, penalty='l2', random_state=None,
#            refit=True, scoring=None, solver='lbfgs', tol=1e-10, verbose=0)

# %%
preds = model.predict(X_train)
print classification_report(y_train, preds)
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.76      0.92      0.83       275
#         1.0       0.89      0.69      0.78       261
#
# avg / total       0.82      0.81      0.80       536

# %%
temp = df_merged[preds==1]
temp['Longitude'].describe()
# Out:
# count    202.000000
# mean     -73.924089
# std        0.093608
# min      -74.243221
# 25%      -73.978458
# 50%      -73.925924
# 75%      -73.863707
# max      -73.713022
# Name: Longitude, dtype: float64

# %%
feature_importance = model.coef_[0]

feature_importance_min = feature_importance.min()
feature_importance_max = feature_importance.max()
feature_importance = (feature_importance - feature_importance_min) / (feature_importance_max - feature_importance_min)

# %%
feature_importance_dict = dict(zip(feature_list, feature_importance))
feature_importance_dict = sorted(feature_importance_dict.iteritems(), key=lambda (k, v): (v, k), reverse=True)
feature_importance_dict
# Out:
# [('Longitude', 1.0),
#  ('Grade 6 ELA - All Students Tested', 0.8913836438233415),
#  ('Grade 6 Math 4s - All Students', 0.8911186886585374),
#  ('Grade 6 Math - All Students Tested', 0.8878174663349611),
#  ('Grade 7 Math 4s - All Students', 0.8005617659344898),
#  ('Grade 6 ELA 4s - All Students', 0.7996703725060211),
#  ('Grade 6 Math 4s - Economically Disadvantaged', 0.7713901734909349),
#  ('Grade 8 ELA 4s - All Students', 0.7581365814352017),
#  ('Grade 7 ELA 4s - All Students', 0.7560733233122792),
#  ('Grade 7 Math - All Students Tested', 0.7394261880445615),
#  ('Grade 7 ELA - All Students Tested', 0.7299442974250293),
#  ('Grade 5 Math - All Students Tested', 0.725397443185781),
#  ('Grade 4 Math 4s - All Students', 0.7247703798838062),
#  ('Grade 5 ELA - All Students Tested', 0.7219534711051477),
#  ('Grade 7 Math 4s - Economically Disadvantaged', 0.7175214116982919),
#  ('Grade 6 Math 4s - Asian or Pacific Islander', 0.7123035669532564),
#  ('Grade 6 ELA 4s - Economically Disadvantaged', 0.7121575165154366),
#  ('Percent Asian', 0.7115185063338227),
#  ('Grade 3 Math 4s - All Students', 0.7108137803449126),
#  ('Grade 8 ELA 4s - Economically Disadvantaged', 0.6919757762907224),
#  ('Grade 8 Math 4s - All Students', 0.6906749281202245),
#  ('Grade 5 Math 4s - All Students', 0.6905158888928145),
#  ('Grade 7 Math 4s - Asian or Pacific Islander', 0.6889248007991425),
#  ('Grade 4 Math 4s - Economically Disadvantaged', 0.6885093981583221),
#  ('Grade 4 Math - All Students Tested', 0.6866677955282813),
#  ('Grade 4 ELA - All Students Tested', 0.6862972895913729),
#  ('Grade 6 Math 4s - Black or African American', 0.6856946284779064),
#  ('Grade 4 ELA 4s - All Students', 0.683294519428205),
#  ('Grade 3 Math 4s - Economically Disadvantaged', 0.6828268032843783),
#  ('Grade 3 Math - All Students tested', 0.6827359139003046),
#  ('Grade 7 ELA 4s - Economically Disadvantaged', 0.6826342374716581),
#  ('Grade 3 ELA - All Students Tested', 0.6800013496277763),
#  ('Grade 4 Math 4s - Black or African American', 0.6765812793846185),
#  ('Grade 6 Math 4s - White', 0.6751063380906094),
#  ('Grade 6 ELA 4s - Asian or Pacific Islander', 0.6744091898634342),
#  ('Grade 3 Math 4s - Black or African American', 0.6716001095755278),
#  ('Grade 8 ELA - All Students Tested', 0.6694754695876223),
#  ('Grade 6 ELA 4s - White', 0.6680934358131528),
#  ('Grade 5 Math 4s - Economically Disadvantaged', 0.6679146475957071),
#  ('Grade 8 Math 4s - Economically Disadvantaged', 0.6671400982779733),
#  ('Grade 5 ELA 4s - All Students', 0.6663520331653903),
#  ('Grade 8 ELA 4s - Asian or Pacific Islander', 0.6660299796918173),
#  ('Grade 7 ELA 4s - Asian or Pacific Islander', 0.6647484605821886),
#  ('Grade 6 Math 4s - Hispanic or Latino', 0.6622999113994453),
#  ('Grade 7 Math 4s - White', 0.6615195590318013),
#  ('Grade 6 ELA 4s - Black or African American', 0.6608012517376745),
#  ('Grade 3 ELA 4s - All Students', 0.6601801078431792),
#  ('Grade 4 ELA 4s - Economically Disadvantaged', 0.6599882216689765),
#  ('Grade 7 ELA 4s - White', 0.6586364089301605),
#  ('Grade 8 ELA 4s - White', 0.6525895883084899),
#  ('Grade 4 ELA 4s - Black or African American', 0.6508763869098111),
#  ('Grade 7 Math 4s - Black or African American', 0.6507256984386802),
#  ('Grade 8 Math 4s - Asian or Pacific Islander', 0.6499764474995351),
#  ('Grade 5 Math 4s - Black or African American', 0.6494247419291622),
#  ('Grade 5 ELA 4s - Economically Disadvantaged', 0.647639266460909),
#  ('Grade 6 ELA 4s - Hispanic or Latino', 0.645218373583729),
#  ('Grade 3 ELA 4s - Economically Disadvantaged', 0.6450667184657433),
#  ('Grade 8 ELA 4s - Black or African American', 0.6439670605560618),
#  ('Grade 8 Math 4s - Black or African American', 0.6431007249648611),
#  ('Grade 7 Math 4s - Hispanic or Latino', 0.6418754309788143),
#  ('Grade 7 ELA 4s - Hispanic or Latino', 0.6413110384763935),
#  ('Grade 8 ELA 4s - Hispanic or Latino', 0.6408364917528342),
#  ('Grade 3 ELA 4s - Black or African American', 0.6401163951953114),
#  ('Grade 3 Math 4s - Asian or Pacific Islander', 0.639655562682802),
#  ('Grade 4 Math 4s - Asian or Pacific Islander', 0.6394419350018625),
#  ('Grade 5 ELA 4s - Black or African American', 0.6379239035869916),
#  ('Grade 7 ELA 4s - Black or African American', 0.6378535107279493),
#  ('Grade 4 Math 4s - Hispanic or Latino', 0.6352306046053194),
#  ('Grade 4 ELA 4s - Asian or Pacific Islander', 0.6348175207736345),
#  ('Percent White', 0.6337935953443485),
#  ('Grade 5 Math 4s - Asian or Pacific Islander', 0.6330969698287774),
#  ('Grade 8 Math 4s - White', 0.6322394483240168),
#  ('Grade 3 Math 4s - Hispanic or Latino', 0.6310761915215871),
#  ('Grade 5 ELA 4s - Asian or Pacific Islander', 0.6298075765582013),
#  ('Grade 5 Math 4s - Hispanic or Latino', 0.629652648319137),
#  ('Grade 4 ELA 4s - Hispanic or Latino', 0.6279228771062003),
#  ('Grade 5 ELA 4s - White', 0.6271234963488261),
#  ('Grade 3 ELA 4s - Asian or Pacific Islander', 0.6269409296868579),
#  ('Grade 3 ELA 4s - Hispanic or Latino', 0.6264461962141176),
#  ('Grade 5 Math 4s - White', 0.6245891898150262),
#  ('Grade 5 ELA 4s - Hispanic or Latino', 0.6234755627070411),
#  ('Grade 6 Math 4s - Limited English Proficient', 0.6230097404070413),
#  ('Grade 4 ELA 4s - White', 0.6228771979317331),
#  ('Grade 6 ELA 4s - Multiracial', 0.6224049476378679),
#  ('Grade 6 Math 4s - Multiracial', 0.6222374733281892),
#  ('Grade 3 ELA 4s - White', 0.6219476139651685),
#  ('Grade 4 Math 4s - White', 0.621390942740859),
#  ('Grade 7 Math 4s - Limited English Proficient', 0.6212439177655714),
#  ('Grade 8 Math 4s - Limited English Proficient', 0.6210997741895982),
#  ('Grade 4 Math 4s - Multiracial', 0.6208786101478283),
#  ('Grade 3 Math 4s - Limited English Proficient', 0.6205867978677018),
#  ('Grade 3 Math 4s - Multiracial', 0.620531521001474),
#  ('Grade 4 ELA 4s - Multiracial', 0.6204556316962767),
#  ('Grade 8 Math 4s - Hispanic or Latino', 0.6204386448008915),
#  ('Grade 7 ELA 4s - Multiracial', 0.6202945497780534),
#  ('Grade 7 Math 4s - Multiracial', 0.6202903342814909),
#  ('Grade 5 ELA 4s - Multiracial', 0.6202794966484546),
#  ('Grade 5 Math 4s - Multiracial', 0.6199531476922663),
#  ('Grade 3 ELA 4s - Multiracial', 0.6199174005323456),
#  ('Grade 3 Math 4s - American Indian or Alaska Native', 0.6198891010108376),
#  ('Grade 7 Math 4s - American Indian or Alaska Native', 0.6197920115608998),
#  ('Grade 8 ELA 4s - American Indian or Alaska Native', 0.6197900734129297),
#  ('Grade 5 Math 4s - Limited English Proficient', 0.6196875092467845),
#  ('Grade 4 Math 4s - American Indian or Alaska Native', 0.6196802406841365),
#  ('Grade 4 Math 4s - Limited English Proficient', 0.6196642293968244),
#  ('Grade 6 ELA 4s - American Indian or Alaska Native', 0.6196096539403417),
#  ('Grade 5 ELA 4s - American Indian or Alaska Native', 0.6195748330412311),
#  ('Grade 8 ELA 4s - Limited English Proficient', 0.619549249452347),
#  ('Grade 5 ELA 4s - Limited English Proficient', 0.619533180994114),
#  ('Grade 3 ELA 4s - Limited English Proficient', 0.6195319514858652),
#  ('Grade 8 ELA 4s - Multiracial', 0.6195239047334574),
#  ('Grade 4 ELA 4s - American Indian or Alaska Native', 0.6195115710025516),
#  ('Grade 5 Math 4s - American Indian or Alaska Native', 0.6194932395186877),
#  ('Grade 8 Math 4s - American Indian or Alaska Native', 0.6194668572484207),
#  ('Grade 7 ELA 4s - Limited English Proficient', 0.6194628516272107),
#  ('Grade 8 Math 4s - Multiracial', 0.6194620552932623),
#  ('Grade 3 ELA 4s - American Indian or Alaska Native', 0.6194553477753566),
#  ('Grade 4 ELA 4s - Limited English Proficient', 0.6193327510696675),
#  ('Grade 6 Math 4s - American Indian or Alaska Native', 0.6191577893244986),
#  ('Grade 7 ELA 4s - American Indian or Alaska Native', 0.6190310929297492),
#  ('Grade 6 ELA 4s - Limited English Proficient', 0.6188356122854392),
#  ('Grade 3 Math 4s - White', 0.6186302236914489),
#  ('IsCommunitySchool', 0.6182387147267646),
#  ('Borough', 0.6086392761503605),
#  ('District', 0.5669081637505343),
#  ('Grade High', 0.5648963924086764),
#  ('City', 0.5181859176195639),
#  ('Percent ELL', 0.5055393493150093),
#  ('Grade 8 Math - All Students Tested', 0.5002425937241934),
#  ('Percent Black', 0.421778640110525),
#  ('Latitude', 0.4095559347374015),
#  ('Percent Hispanic', 0.1995202913866571),
#  ('Percent Black / Hispanic', 0.0)]
